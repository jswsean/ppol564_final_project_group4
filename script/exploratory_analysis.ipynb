# %% [markdown]
# # Pre-amble

# %%
# loading the required packages
import pandas as pd
import numpy as np
import datetime
import random
import re
import os
import plotnine
from plotnine import *

# for repeated printouts 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# to custom displays of row-column df printouts
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # Data import

# %% [markdown]
# Here, we'll load our analysis-ready sentencing data, and print out some of the basic information about the data:

# %%
# loading the analysis-ready dataset
sentencing_analysis = pd.read_csv('../data/csv/sentencing_analysis.csv')
# Out:
# C:\Users\Sean Hambali\AppData\Local\Temp\ipykernel_9336\2683187563.py:2: DtypeWarning: Columns (10,11,14,25) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
# printing out basic dataset info
sentencing_analysis.dtypes
# Out:
# CASE_ID                                int64
# CASE_PARTICIPANT_ID                    int64
# RECEIVED_DATE                         object
# OFFENSE_CATEGORY                      object
# PRIMARY_CHARGE_FLAG                     bool
# CHARGE_ID                              int64
# CHARGE_VERSION_ID                      int64
# DISPOSITION_CHARGED_OFFENSE_TITLE     object
# CHARGE_COUNT                           int64
# DISPOSITION_DATE                      object
# DISPOSITION_CHARGED_CHAPTER           object
# DISPOSITION_CHARGED_ACT               object
# DISPOSITION_CHARGED_SECTION           object
# DISPOSITION_CHARGED_CLASS             object
# DISPOSITION_CHARGED_AOIC              object
# CHARGE_DISPOSITION                    object
# CHARGE_DISPOSITION_REASON             object
# SENTENCE_JUDGE                        object
# SENTENCE_COURT_NAME                   object
# SENTENCE_COURT_FACILITY               object
# SENTENCE_PHASE                        object
# SENTENCE_DATE                         object
# SENTENCE_TYPE                         object
# CURRENT_SENTENCE_FLAG                   bool
# COMMITMENT_TYPE                       object
# COMMITMENT_TERM                       object
# COMMITMENT_UNIT                       object
# LENGTH_OF_CASE_in_Days               float64
# AGE_AT_INCIDENT                      float64
# RACE                                  object
# GENDER                                object
# INCIDENT_CITY                         object
# INCIDENT_BEGIN_DATE                   object
# INCIDENT_END_DATE                     object
# LAW_ENFORCEMENT_AGENCY                object
# LAW_ENFORCEMENT_UNIT                  object
# ARREST_DATE                           object
# FELONY_REVIEW_DATE                    object
# FELONY_REVIEW_RESULT                  object
# ARRAIGNMENT_DATE                      object
# UPDATED_OFFENSE_CATEGORY              object
# is_black                              object
# is_hisp                               object
# is_white                              object
# is_female                            float64
# age_cleaned                          float64
# sentence_date                         object
# sentence_year                          int64
# sentence_month                         int64
# sentence_day                           int64
# sentence_ym                           object
# sa_office_period                        bool
# BRA_period                              bool
# eligible_offense                        bool
# sentencing_num                       float64
# sentencing_term_d                    float64
# sentencing_term_y                    float64
# is_incarcerated                         bool
# is_on_probation                         bool
# regrouped_offense                     object
# dtype: object

# %%
# printing a sample of the dataset
sentencing_analysis.sample(n=10)
# Out:
#              CASE_ID  CASE_PARTICIPANT_ID           RECEIVED_DATE  \
# 146878  565253988507         414541074488  10/19/2017 12:00:00 AM
# 66445   528353403781         371372639636  05/11/2013 12:00:00 AM
# 31843   513846764671         355996049106  11/01/2011 12:00:00 AM
# 2008    299181443263         109180781577  11/01/2009 12:00:00 AM
# 47550   520353845946         362731529937  07/13/2012 12:00:00 AM
# 142871  562972062733         411829147002  07/03/2017 12:00:00 AM
# 183228  590608999849         444590804205  04/23/2021 12:00:00 AM
# 74525   531906410762         375444200685  09/19/2013 12:00:00 AM
# 167114  577339261612         428341027402  05/10/2019 12:00:00 AM
# 144294  563774912192         412786115950  08/09/2017 12:00:00 AM
#
#                          OFFENSE_CATEGORY  PRIMARY_CHARGE_FLAG  \
# 146878  Aggravated Battery Police Officer                 True
# 66445                  Aggravated Battery                 True
# 31843                           Narcotics                 True
# 2008                    PROMIS Conversion                 True
# 47550                           Narcotics                 True
# 142871                          Narcotics                 True
# 183228                   Domestic Battery                 True
# 74525                           Narcotics                 True
# 167114                          Narcotics                 True
# 144294                    Child Abduction                 True
#
#              CHARGE_ID  CHARGE_VERSION_ID  \
# 146878  10298356371152      1045308504931
# 66445    9081325673433       919776011528
# 31843    8634863389667       874032206988
# 2008     3146453173229       850291284584
# 47550    8826511710291       893692529417
# 142871  10211637920205      1060237571924
# 183228  11058858985671      1123914661252
# 74525    9188784048188       930773639184
# 167114  10681055815358      1085047499745
# 144294  10233878873433      1077754382205
#
#                         DISPOSITION_CHARGED_OFFENSE_TITLE  CHARGE_COUNT  \
# 146878                       RESIST/PC OFF/CORR/FRFTR/INJ             1
# 66445                         AGGRAVATED DOMESTIC BATTERY             1
# 31843   [POSSESSION OF CONTROLLED SUBSTANCE WITH INTEN...             1
# 2008                 POSSESSION OF A CONTROLLED SUBSTANCE             1
# 47550   [POSSESSION OF CANNABIS WITH INTENT TO DELIVER...             1
# 142871               POSSESSION OF A CONTROLLED SUBSTANCE             1
# 183228                         DOM BTRY/HARM/1-2  PRECONV             1
# 74525                POSSESSION OF A CONTROLLED SUBSTANCE             1
# 167114               POSSESSION OF A CONTROLLED SUBSTANCE             1
# 144294                                 DISORDERLY CONDUCT             1
#
#               DISPOSITION_DATE DISPOSITION_CHARGED_CHAPTER  \
# 146878  07/25/2018 12:00:00 AM                         720
# 66445   07/24/2013 12:00:00 AM                         720
# 31843   01/23/2012 12:00:00 AM                         720
# 2008    01/12/2011 12:00:00 AM                         720
# 47550   08/24/2012 12:00:00 AM                         720
# 142871  06/04/2018 12:00:00 AM                         720
# 183228  10/20/2021 12:00:00 AM                         720
# 74525   06/18/2014 12:00:00 AM                         720
# 167114  09/16/2019 12:00:00 AM                         720
# 144294  01/23/2019 12:00:00 AM                         720
#
#        DISPOSITION_CHARGED_ACT DISPOSITION_CHARGED_SECTION  \
# 146878                       5                   31-1(a-7)
# 66445                        5                 12-3.3(a-5)
# 31843                      570                   401(c)(1)
# 2008                       570                      402(c)
# 47550                      550                      5.2(d)
# 142871                     570                      402(c)
# 183228                       5                12-3.2(a)(1)
# 74525                      570                      402(c)
# 167114                     570                      402(c)
# 144294                       5                  26-1(a)(1)
#
#        DISPOSITION_CHARGED_CLASS DISPOSITION_CHARGED_AOIC CHARGE_DISPOSITION  \
# 146878                         4                  0014799     Plea Of Guilty
# 66445                          2                  0014834     Plea Of Guilty
# 31843                          1                  0013009     Plea Of Guilty
# 2008                           4                  5101110     Finding Guilty
# 47550                          4                  0010365     Plea Of Guilty
# 142871                         4                  5101110     Plea Of Guilty
# 183228                         4                    17578     Plea Of Guilty
# 74525                          4                  5101110     Plea Of Guilty
# 167114                         4                  5101110     Plea Of Guilty
# 144294                         C                  1255000     Plea Of Guilty
#
#        CHARGE_DISPOSITION_REASON         SENTENCE_JUDGE  \
# 146878                       NaN      Thomas J Hennelly
# 66445                        NaN           James B Linn
# 31843                        NaN        Charles P Burns
# 2008                         NaN           John T Doody
# 47550                        NaN        Nicholas R Ford
# 142871                       NaN  Angela Munari Petrone
# 183228                       NaN     Terence  MacCarthy
# 74525                        NaN        Kevin M Sheehan
# 167114                       NaN       Pamela A Leeming
# 144294                       NaN     Stephen J Connolly
#
#             SENTENCE_COURT_NAME SENTENCE_COURT_FACILITY  \
# 146878     District 1 - Chicago             26TH Street
# 66445      District 1 - Chicago             26TH Street
# 31843      District 1 - Chicago             26TH Street
# 2008       District 1 - Chicago             26TH Street
# 47550      District 1 - Chicago             26TH Street
# 142871     District 1 - Chicago             26TH Street
# 183228     District 4 - Maywood      Maywood Courthouse
# 74525      District 1 - Chicago             26TH Street
# 167114     District 4 - Maywood      Maywood Courthouse
# 144294  District 5 - Bridgeview   Bridgeview Courthouse
#
#                       SENTENCE_PHASE           SENTENCE_DATE SENTENCE_TYPE  \
# 146878           Original Sentencing  07/25/2018 12:00:00 AM        Prison
# 66445            Original Sentencing  07/24/2013 12:00:00 AM        Prison
# 31843   Amended/Corrected Sentencing  01/23/2012 12:00:00 AM        Prison
# 2008             Original Sentencing  01/12/2011 12:00:00 AM        Prison
# 47550            Original Sentencing  08/22/2012 12:00:00 AM     Probation
# 142871           Original Sentencing  06/01/2018 12:00:00 AM        Prison
# 183228           Original Sentencing  10/20/2021 12:00:00 AM        Prison
# 74525            Original Sentencing  06/18/2014 12:00:00 AM        Prison
# 167114           Original Sentencing  09/16/2019 12:00:00 AM        Prison
# 144294           Original Sentencing  01/23/2019 12:00:00 AM   Supervision
#
#         CURRENT_SENTENCE_FLAG                     COMMITMENT_TYPE  \
# 146878                   True  Illinois Department of Corrections
# 66445                    True  Illinois Department of Corrections
# 31843                    True  Illinois Department of Corrections
# 2008                     True  Illinois Department of Corrections
# 47550                    True                           Probation
# 142871                   True  Illinois Department of Corrections
# 183228                   True  Illinois Department of Corrections
# 74525                    True  Illinois Department of Corrections
# 167114                   True  Illinois Department of Corrections
# 144294                   True                   Court Supervision
#
#        COMMITMENT_TERM COMMITMENT_UNIT  LENGTH_OF_CASE_in_Days  \
# 146878             2.0         Year(s)                   240.0
# 66445              3.0         Year(s)                    33.0
# 31843              2.0         Year(s)                    47.0
# 2008               3.5         Year(s)                     NaN
# 47550                2         Year(s)                     0.0
# 142871             3.0         Year(s)                   296.0
# 183228            18.0          Months                   146.0
# 74525             18.0          Months                   166.0
# 167114             3.0         Year(s)                    88.0
# 144294            18.0          Months                   503.0
#
#         AGE_AT_INCIDENT   RACE GENDER  INCIDENT_CITY     INCIDENT_BEGIN_DATE  \
# 146878             23.0  Black   Male        Chicago  10/12/2017 12:00:00 AM
# 66445              34.0  Black   Male        Chicago  05/10/2013 12:00:00 AM
# 31843              19.0  Black   Male        Chicago  10/29/2011 12:00:00 AM
# 2008               39.0  Black   Male            NaN  10/31/2009 12:00:00 AM
# 47550              20.0  Black   Male        Chicago  07/11/2012 12:00:00 AM
# 142871             58.0  Black   Male        Chicago  05/11/2017 12:00:00 AM
# 183228             34.0  White   Male         Cicero  04/21/2021 12:00:00 AM
# 74525              46.0  Black   Male        Chicago  09/17/2013 12:00:00 AM
# 167114             34.0  Black   Male        Maywood  04/19/2019 12:00:00 AM
# 144294             70.0  White   Male  Hickory Hills  08/09/2017 12:00:00 AM
#
#        INCIDENT_END_DATE           LAW_ENFORCEMENT_AGENCY  \
# 146878               NaN  COOK COUNTY SHERIFF (IL0160000)
# 66445                NaN                       CHICAGO PD
# 31843                NaN                       CHICAGO PD
# 2008                 NaN             C P D AREA 4 DIST 11
# 47550                NaN                       CHICAGO PD
# 142871               NaN                       CHICAGO PD
# 183228               NaN                        CICERO PD
# 74525                NaN                       CHICAGO PD
# 167114               NaN              ISP DII DES PLAINES
# 144294               NaN                 HICKORY HILLS PD
#
#           LAW_ENFORCEMENT_UNIT             ARREST_DATE  \
# 146878                     NaN  10/19/2017 07:50:00 AM
# 66445                      NaN  05/10/2013 02:15:00 PM
# 31843   District 11 - Harrison  10/29/2011 04:30:00 PM
# 2008                       NaN  10/31/2009 07:35:00 PM
# 47550      District 10 - Ogden  07/11/2012 10:15:00 PM
# 142871                     NaN  06/29/2017 04:04:00 PM
# 183228                     NaN  04/22/2021 10:35:00 PM
# 74525   District 11 - Harrison  09/17/2013 07:20:00 PM
# 167114                     NaN  04/26/2019 05:17:00 AM
# 144294                     NaN  08/09/2017 01:00:00 PM
#
#             FELONY_REVIEW_DATE FELONY_REVIEW_RESULT        ARRAIGNMENT_DATE  \
# 146878  10/19/2017 12:00:00 AM             Approved  11/27/2017 12:00:00 AM
# 66445   05/11/2013 12:00:00 AM             Approved  06/21/2013 12:00:00 AM
# 31843                      NaN                  NaN  12/07/2011 12:00:00 AM
# 2008                       NaN                  NaN                     NaN
# 47550                      NaN                  NaN  08/22/2012 12:00:00 AM
# 142871                     NaN                  NaN  08/09/2017 12:00:00 AM
# 183228  04/23/2021 12:00:00 AM             Approved  05/27/2021 12:00:00 AM
# 74525                      NaN                  NaN  01/03/2014 12:00:00 AM
# 167114                     NaN                  NaN  06/20/2019 12:00:00 AM
# 144294  08/10/2017 12:00:00 AM             Approved  09/07/2017 12:00:00 AM
#
#        UPDATED_OFFENSE_CATEGORY is_black is_hisp is_white  is_female  \
# 146878            Other Offense     True   False    False        0.0
# 66445          Domestic Battery     True   False    False        0.0
# 31843                 Narcotics     True   False    False        0.0
# 2008          PROMIS Conversion     True   False    False        0.0
# 47550                 Narcotics     True   False    False        0.0
# 142871                Narcotics     True   False    False        0.0
# 183228         Domestic Battery    False   False     True        0.0
# 74525                 Narcotics     True   False    False        0.0
# 167114                Narcotics     True   False    False        0.0
# 144294          Child Abduction    False   False     True        0.0
#
#         age_cleaned sentence_date  sentence_year  sentence_month  \
# 146878         23.0    2018-07-25           2018               7
# 66445          34.0    2013-07-24           2013               7
# 31843          19.0    2012-01-23           2012               1
# 2008           39.0    2011-01-12           2011               1
# 47550          20.0    2012-08-22           2012               8
# 142871         58.0    2018-06-01           2018               6
# 183228         34.0    2021-10-20           2021              10
# 74525          46.0    2014-06-18           2014               6
# 167114         34.0    2019-09-16           2019               9
# 144294         70.0    2019-01-23           2019               1
#
#         sentence_day sentence_ym  sa_office_period  BRA_period  \
# 146878            25     2018-07              True        True
# 66445             24     2013-07             False       False
# 31843             23     2012-01             False       False
# 2008              12     2011-01             False       False
# 47550             22     2012-08             False       False
# 142871             1     2018-06              True        True
# 183228            20     2021-10              True        True
# 74525             18     2014-06             False       False
# 167114            16     2019-09              True        True
# 144294            23     2019-01              True        True
#
#         eligible_offense  sentencing_num  sentencing_term_d  \
# 146878              True             2.0              730.0
# 66445              False             3.0             1095.0
# 31843              False             2.0              730.0
# 2008                True             3.5             1277.5
# 47550               True             2.0              730.0
# 142871              True             3.0             1095.0
# 183228              True            18.0              549.0
# 74525               True            18.0              549.0
# 167114              True             3.0             1095.0
# 144294              True            18.0              549.0
#
#         sentencing_term_y  is_incarcerated  is_on_probation  regrouped_offense
# 146878            2.00000             True            False      Other Offense
# 66445             3.00000             True            False   Domestic Battery
# 31843             2.00000             True            False          Narcotics
# 2008              3.50000             True            False  PROMIS Conversion
# 47550             2.00000            False             True          Narcotics
# 142871            3.00000             True            False          Narcotics
# 183228            1.50411             True            False   Domestic Battery
# 74525             1.50411             True            False          Narcotics
# 167114            3.00000             True            False          Narcotics
# 144294            1.50411            False            False    Child Abduction

# %%
# what's the shape of the data? 
print("Data shape: " + str(sentencing_analysis.shape))
# Out:
# Data shape: (186824, 60)

# %% [markdown]
# # Research questions:

# %% [markdown]
# Here, we aim to provide some preliminary tabulations on the following questions:
#
# 1. Does State Attorney Kim Foxx's entry lead to any changes in black-white incarceration probability?
# 2. Does State Attorney Kim Foxx's entry lead to any changes in black-white probability of probation?
# 3. Does State Attorney Kim Foxx's entry lead to any changes in black-white sentencing time?
# 4. How does the above dynamic differ by eligible/non-eligible cases?

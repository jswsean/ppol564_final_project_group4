# %% [markdown]
# # Table of contents
#
# This cleaning/exploration script is structured as follows:
# 1. [Pre-amble](#pre-amble)
#
# 2. [Basic dataset information](#basic-info)
#
# 3. [Data cleaning](#data-cleaning)
#
#     * [Basic demographics](#basic-demographics)
#     * [Date-time variables](#datetime-variables)
#     * [Sentencing variables](#sentencing-variables)
#     * [Filtering to prepare analysis-ready datasets](#filtering)
#     * [Regrouping offenses using CJARS tool](#cjars)

# %% [markdown]
# # Pre-amble<a class="anchor" id="pre-amble"></a>

# %% [markdown]
# Prior to the exploration, we first load some basic packages:

# %%
# loading the required packages
import pandas as pd
import numpy as np
import datetime
import random
import re
import os
from dateutil import relativedelta
#import plotnine
#from plotnine import *

# for repeated printouts 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# to custom displays of row-column df printouts
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 120)

# %% [markdown]
# # Basic dataset information<a class="anchor" id="basic-info"></a>

# %%
# loading the raw sentencing data 
sentencing_raw = pd.read_csv('../data/csv/sentencing.csv')

# printing the dataset characteristics
sentencing_raw.shape
sentencing_raw.info()
sentencing_raw.dtypes

# taking a look at the data head
sentencing_raw.head(n=10)
# Out:
# C:\Users\Sean Hambali\AppData\Local\Temp\ipykernel_22084\2838289327.py:2: DtypeWarning: Columns (10,11,14,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   sentencing_raw = pd.read_csv('../data/csv/sentencing.csv')
# (272294, 41)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272294 entries, 0 to 272293
# Data columns (total 41 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   CASE_ID                            272294 non-null  int64
#  1   CASE_PARTICIPANT_ID                272294 non-null  int64
#  2   RECEIVED_DATE                      272294 non-null  object
#  3   OFFENSE_CATEGORY                   272294 non-null  object
#  4   PRIMARY_CHARGE_FLAG                272294 non-null  bool
#  5   CHARGE_ID                          272294 non-null  int64
#  6   CHARGE_VERSION_ID                  272294 non-null  int64
#  7   DISPOSITION_CHARGED_OFFENSE_TITLE  272294 non-null  object
#  8   CHARGE_COUNT                       272294 non-null  int64
#  9   DISPOSITION_DATE                   272294 non-null  object
#  10  DISPOSITION_CHARGED_CHAPTER        272294 non-null  object
#  11  DISPOSITION_CHARGED_ACT            266886 non-null  object
#  12  DISPOSITION_CHARGED_SECTION        266886 non-null  object
#  13  DISPOSITION_CHARGED_CLASS          272275 non-null  object
#  14  DISPOSITION_CHARGED_AOIC           272270 non-null  object
#  15  CHARGE_DISPOSITION                 272294 non-null  object
#  16  CHARGE_DISPOSITION_REASON          1119 non-null    object
#  17  SENTENCE_JUDGE                     271552 non-null  object
#  18  SENTENCE_COURT_NAME                270905 non-null  object
#  19  SENTENCE_COURT_FACILITY            270189 non-null  object
#  20  SENTENCE_PHASE                     272294 non-null  object
#  21  SENTENCE_DATE                      272294 non-null  object
#  22  SENTENCE_TYPE                      272294 non-null  object
#  23  CURRENT_SENTENCE_FLAG              272294 non-null  bool
#  24  COMMITMENT_TYPE                    270539 non-null  object
#  25  COMMITMENT_TERM                    270508 non-null  object
#  26  COMMITMENT_UNIT                    270508 non-null  object
#  27  LENGTH_OF_CASE_in_Days             253420 non-null  float64
#  28  AGE_AT_INCIDENT                    268527 non-null  float64
#  29  RACE                               270917 non-null  object
#  30  GENDER                             271436 non-null  object
#  31  INCIDENT_CITY                      251737 non-null  object
#  32  INCIDENT_BEGIN_DATE                269365 non-null  object
#  33  INCIDENT_END_DATE                  24039 non-null   object
#  34  LAW_ENFORCEMENT_AGENCY             271981 non-null  object
#  35  LAW_ENFORCEMENT_UNIT               82716 non-null   object
#  36  ARREST_DATE                        266617 non-null  object
#  37  FELONY_REVIEW_DATE                 191498 non-null  object
#  38  FELONY_REVIEW_RESULT               191498 non-null  object
#  39  ARRAIGNMENT_DATE                   253420 non-null  object
#  40  UPDATED_OFFENSE_CATEGORY           272294 non-null  object
# dtypes: bool(2), float64(2), int64(5), object(32)
# memory usage: 81.5+ MB
# CASE_ID                                int64
# CASE_PARTICIPANT_ID                    int64
# RECEIVED_DATE                         object
# OFFENSE_CATEGORY                      object
# PRIMARY_CHARGE_FLAG                     bool
# CHARGE_ID                              int64
# CHARGE_VERSION_ID                      int64
# DISPOSITION_CHARGED_OFFENSE_TITLE     object
# CHARGE_COUNT                           int64
# DISPOSITION_DATE                      object
# DISPOSITION_CHARGED_CHAPTER           object
# DISPOSITION_CHARGED_ACT               object
# DISPOSITION_CHARGED_SECTION           object
# DISPOSITION_CHARGED_CLASS             object
# DISPOSITION_CHARGED_AOIC              object
# CHARGE_DISPOSITION                    object
# CHARGE_DISPOSITION_REASON             object
# SENTENCE_JUDGE                        object
# SENTENCE_COURT_NAME                   object
# SENTENCE_COURT_FACILITY               object
# SENTENCE_PHASE                        object
# SENTENCE_DATE                         object
# SENTENCE_TYPE                         object
# CURRENT_SENTENCE_FLAG                   bool
# COMMITMENT_TYPE                       object
# COMMITMENT_TERM                       object
# COMMITMENT_UNIT                       object
# LENGTH_OF_CASE_in_Days               float64
# AGE_AT_INCIDENT                      float64
# RACE                                  object
# GENDER                                object
# INCIDENT_CITY                         object
# INCIDENT_BEGIN_DATE                   object
# INCIDENT_END_DATE                     object
# LAW_ENFORCEMENT_AGENCY                object
# LAW_ENFORCEMENT_UNIT                  object
# ARREST_DATE                           object
# FELONY_REVIEW_DATE                    object
# FELONY_REVIEW_RESULT                  object
# ARRAIGNMENT_DATE                      object
# UPDATED_OFFENSE_CATEGORY              object
# dtype: object
#         CASE_ID  CASE_PARTICIPANT_ID           RECEIVED_DATE  \
# 0  198055620664          85937621020  08/15/1984 12:00:00 AM
# 1  198055620664          85937621020  08/15/1984 12:00:00 AM
# 2  198055620664          85937621020  08/15/1984 12:00:00 AM
# 3  198055620664          85937621020  08/15/1984 12:00:00 AM
# 4  198055620664          85937621020  08/15/1984 12:00:00 AM
# 5  198055620664          85937621020  08/15/1984 12:00:00 AM
# 6  198055620664          85937621020  08/15/1984 12:00:00 AM
# 7  198055620664          85937621020  08/15/1984 12:00:00 AM
# 8  198055620664          85937621020  08/15/1984 12:00:00 AM
# 9  198055620664          85937621020  08/15/1984 12:00:00 AM
#
#     OFFENSE_CATEGORY  PRIMARY_CHARGE_FLAG      CHARGE_ID  CHARGE_VERSION_ID  \
# 0  PROMIS Conversion                False  1242195814523       155656315869
# 1  PROMIS Conversion                False  1242198287388       131513547452
# 2  PROMIS Conversion                False  1242351605056       176626576281
# 3  PROMIS Conversion                False  1242352841488       176617824190
# 4  PROMIS Conversion                False  1242356550787       131238606761
# 5  PROMIS Conversion                False  1242356550787       131238606761
# 6  PROMIS Conversion                False  1242357787220       150253900073
# 7  PROMIS Conversion                False  1242357787220       150253900073
# 8  PROMIS Conversion                False  1242359023652       150251649536
# 9  PROMIS Conversion                 True  1242194578090       151097726688
#
#   DISPOSITION_CHARGED_OFFENSE_TITLE  CHARGE_COUNT        DISPOSITION_DATE  \
# 0               FIRST DEGREE MURDER             2  12/17/2014 12:00:00 AM
# 1                     HOME INVASION            14  12/17/2014 12:00:00 AM
# 2               FIRST DEGREE MURDER             4  12/17/2014 12:00:00 AM
# 3               FIRST DEGREE MURDER             5  12/17/2014 12:00:00 AM
# 4                     HOME INVASION            13  12/17/2014 12:00:00 AM
# 5                     HOME INVASION            13  12/17/2014 12:00:00 AM
# 6                     ARMED ROBBERY            15  12/17/2014 12:00:00 AM
# 7                     ARMED ROBBERY            15  12/17/2014 12:00:00 AM
# 8                     ARMED ROBBERY            16  12/17/2014 12:00:00 AM
# 9               FIRST DEGREE MURDER             1  12/17/2014 12:00:00 AM
#
#   DISPOSITION_CHARGED_CHAPTER DISPOSITION_CHARGED_ACT  \
# 0                          38                       -
# 1               38-12-11-A(2)                     NaN
# 2                          38                       -
# 3                          38                       -
# 4               38-12-11-A(1)                     NaN
# 5               38-12-11-A(1)                     NaN
# 6                   38-18-2-A                     NaN
# 7                   38-18-2-A                     NaN
# 8                   38-18-2-A                     NaN
# 9                          38                       -
#
#   DISPOSITION_CHARGED_SECTION DISPOSITION_CHARGED_CLASS  \
# 0                   9-1(a)(2)                         X
# 1                         NaN                         X
# 2                   9-1(a)(3)                         X
# 3                   9-1(a)(3)                         X
# 4                         NaN                         X
# 5                         NaN                         X
# 6                         NaN                         X
# 7                         NaN                         X
# 8                         NaN                         X
# 9                   9-1(a)(1)                         X
#
#   DISPOSITION_CHARGED_AOIC CHARGE_DISPOSITION CHARGE_DISPOSITION_REASON  \
# 0               0000001607    Nolle On Remand                       NaN
# 1               0000001847    Nolle On Remand                       NaN
# 2               0000001608    Nolle On Remand                       NaN
# 3               0000001608    Nolle On Remand                       NaN
# 4               0000001846     Plea Of Guilty                       NaN
# 5               0000001846     Plea Of Guilty                       NaN
# 6               0000002150     Plea Of Guilty                       NaN
# 7               0000002150     Plea Of Guilty                       NaN
# 8               0000002150    Nolle On Remand                       NaN
# 9               0000001606     Plea Of Guilty                       NaN
#
#       SENTENCE_JUDGE   SENTENCE_COURT_NAME SENTENCE_COURT_FACILITY  \
# 0      John  Mannion  District 6 - Markham      Markham Courthouse
# 1      John  Mannion  District 6 - Markham      Markham Courthouse
# 2      John  Mannion  District 6 - Markham      Markham Courthouse
# 3      John  Mannion  District 6 - Markham      Markham Courthouse
# 4  Clayton Jay Crane  District 6 - Markham      Markham Courthouse
# 5      John  Mannion  District 6 - Markham      Markham Courthouse
# 6  Clayton Jay Crane  District 6 - Markham      Markham Courthouse
# 7      John  Mannion  District 6 - Markham      Markham Courthouse
# 8      John  Mannion  District 6 - Markham      Markham Courthouse
# 9  Clayton Jay Crane  District 6 - Markham      Markham Courthouse
#
#                  SENTENCE_PHASE           SENTENCE_DATE SENTENCE_TYPE  \
# 0           Original Sentencing  06/02/1986 12:00:00 AM    Conversion
# 1           Original Sentencing  06/02/1986 12:00:00 AM    Conversion
# 2           Original Sentencing  06/02/1986 12:00:00 AM    Conversion
# 3           Original Sentencing  06/02/1986 12:00:00 AM    Conversion
# 4  Amended/Corrected Sentencing  10/16/2014 12:00:00 AM        Prison
# 5           Original Sentencing  06/02/1986 12:00:00 AM    Conversion
# 6  Amended/Corrected Sentencing  10/16/2014 12:00:00 AM        Prison
# 7           Original Sentencing  06/02/1986 12:00:00 AM    Conversion
# 8           Original Sentencing  06/02/1986 12:00:00 AM    Conversion
# 9  Amended/Corrected Sentencing  10/16/2014 12:00:00 AM        Prison
#
#    CURRENT_SENTENCE_FLAG                     COMMITMENT_TYPE COMMITMENT_TERM  \
# 0                   True                        Natural Life             NaN
# 1                   True  Illinois Department of Corrections            30.0
# 2                   True                        Natural Life             NaN
# 3                   True                        Natural Life             NaN
# 4                   True  Illinois Department of Corrections            30.0
# 5                  False  Illinois Department of Corrections            30.0
# 6                   True  Illinois Department of Corrections            30.0
# 7                  False  Illinois Department of Corrections            30.0
# 8                   True  Illinois Department of Corrections            30.0
# 9                   True  Illinois Department of Corrections            62.0
#
#   COMMITMENT_UNIT  LENGTH_OF_CASE_in_Days  AGE_AT_INCIDENT   RACE GENDER  \
# 0             NaN                   619.0             27.0  Black   Male
# 1         Year(s)                   619.0             27.0  Black   Male
# 2             NaN                   619.0             27.0  Black   Male
# 3             NaN                   619.0             27.0  Black   Male
# 4         Year(s)                 10982.0             27.0  Black   Male
# 5         Year(s)                   619.0             27.0  Black   Male
# 6         Year(s)                 10982.0             27.0  Black   Male
# 7         Year(s)                   619.0             27.0  Black   Male
# 8         Year(s)                   619.0             27.0  Black   Male
# 9         Year(s)                 10982.0             27.0  Black   Male
#
#   INCIDENT_CITY     INCIDENT_BEGIN_DATE INCIDENT_END_DATE  \
# 0           NaN  08/09/1984 12:00:00 AM               NaN
# 1           NaN  08/09/1984 12:00:00 AM               NaN
# 2           NaN  08/09/1984 12:00:00 AM               NaN
# 3           NaN  08/09/1984 12:00:00 AM               NaN
# 4           NaN  08/09/1984 12:00:00 AM               NaN
# 5           NaN  08/09/1984 12:00:00 AM               NaN
# 6           NaN  08/09/1984 12:00:00 AM               NaN
# 7           NaN  08/09/1984 12:00:00 AM               NaN
# 8           NaN  08/09/1984 12:00:00 AM               NaN
# 9           NaN  08/09/1984 12:00:00 AM               NaN
#
#   LAW_ENFORCEMENT_AGENCY LAW_ENFORCEMENT_UNIT             ARREST_DATE  \
# 0    CHICAGO POLICE DEPT                  NaN  08/15/1984 12:00:00 AM
# 1    CHICAGO POLICE DEPT                  NaN  08/15/1984 12:00:00 AM
# 2    CHICAGO POLICE DEPT                  NaN  08/15/1984 12:00:00 AM
# 3    CHICAGO POLICE DEPT                  NaN  08/15/1984 12:00:00 AM
# 4    CHICAGO POLICE DEPT                  NaN  08/15/1984 12:00:00 AM
# 5    CHICAGO POLICE DEPT                  NaN  08/15/1984 12:00:00 AM
# 6    CHICAGO POLICE DEPT                  NaN  08/15/1984 12:00:00 AM
# 7    CHICAGO POLICE DEPT                  NaN  08/15/1984 12:00:00 AM
# 8    CHICAGO POLICE DEPT                  NaN  08/15/1984 12:00:00 AM
# 9    CHICAGO POLICE DEPT                  NaN  08/15/1984 12:00:00 AM
#
#        FELONY_REVIEW_DATE FELONY_REVIEW_RESULT        ARRAIGNMENT_DATE  \
# 0  08/15/1984 12:00:00 AM   Charge(S) Approved  09/21/1984 12:00:00 AM
# 1  08/15/1984 12:00:00 AM   Charge(S) Approved  09/21/1984 12:00:00 AM
# 2  08/15/1984 12:00:00 AM   Charge(S) Approved  09/21/1984 12:00:00 AM
# 3  08/15/1984 12:00:00 AM   Charge(S) Approved  09/21/1984 12:00:00 AM
# 4  08/15/1984 12:00:00 AM   Charge(S) Approved  09/21/1984 12:00:00 AM
# 5  08/15/1984 12:00:00 AM   Charge(S) Approved  09/21/1984 12:00:00 AM
# 6  08/15/1984 12:00:00 AM   Charge(S) Approved  09/21/1984 12:00:00 AM
# 7  08/15/1984 12:00:00 AM   Charge(S) Approved  09/21/1984 12:00:00 AM
# 8  08/15/1984 12:00:00 AM   Charge(S) Approved  09/21/1984 12:00:00 AM
# 9  08/15/1984 12:00:00 AM   Charge(S) Approved  09/21/1984 12:00:00 AM
#
#   UPDATED_OFFENSE_CATEGORY
# 0        PROMIS Conversion
# 1        PROMIS Conversion
# 2        PROMIS Conversion
# 3        PROMIS Conversion
# 4        PROMIS Conversion
# 5        PROMIS Conversion
# 6        PROMIS Conversion
# 7        PROMIS Conversion
# 8        PROMIS Conversion
# 9        PROMIS Conversion

# %% [markdown]
# # Data cleaning<a class="anchor" id="data-cleaning"></a>

# %%
# initializing a df for the cleaned version of the sentencing_raw data 
sentencing_cleaned = sentencing_raw.copy()

# %% [markdown]
# ## Cleaning demographic variables<a class="anchor" id="basic-demographics"></a>
#
# Here, we clean up some important demographic characteristics that can be used in the analysis.
# For this, we adapt some of the approaches that were used in the second and third problem sets.
#
# * Defining the defendant's race groups
# * Defining the defendant's gender group
# * Cleaning up defendant's age via winsorizing

# %%
# printing the original distribution of RACE variable
print("Distribution of original `RACE` variable:")
sentencing_cleaned.RACE.value_counts()

# defining some important race groups
sentencing_cleaned['is_black'] = np.where(sentencing_raw.RACE.isin(['Black', 'White/Black [Hispanic or Latino]']), 
                                          True, False)
sentencing_cleaned['is_hisp'] = np.where(sentencing_raw.RACE.isin(['HISPANIC', 'White [Hispanic or Latino]']), 
                                          True, False)
sentencing_cleaned['is_white'] = np.where(sentencing_raw.RACE.isin(['White']), True, False)

# for the RACE columns, replace value with np.nan if RACE == 'Unknown' or RACE == 'Biracial'
cond = sentencing_cleaned.RACE.isin(['Unknown', 'Biracial']) # defining the condition
sentencing_cleaned.loc[cond, ['is_black', 'is_hisp', 'is_white']] = np.nan
# Out:
# Distribution of original `RACE` variable:
# Black                               181219
# White [Hispanic or Latino]           41976
# White                                37983
# HISPANIC                              6098
# Asian                                 1602
# White/Black [Hispanic or Latino]      1408
# Unknown                                395
# American Indian                        132
# ASIAN                                   68
# Biracial                                36
# Name: RACE, dtype: int64

# %%
# original GENDER distribution:
print("Distribution of original `GENDER` distribution:")
sentencing_cleaned.GENDER.value_counts()

# defining gender groups 
sentencing_cleaned['is_female'] = np.where(sentencing_cleaned.GENDER.isin(['Male', 'Male name, no gender given']), 
                                           False, np.where(sentencing_cleaned.GENDER.str.contains('Unknown'), 
                                                           np.nan, True))

# final look at the gender variable 
print("Distribution of cleaned `is_female` distribution:")
sentencing_cleaned.is_female.value_counts()
# Out:
# Distribution of original `GENDER` distribution:
# Male                          239279
# Female                         32138
# Unknown                           12
# Unknown Gender                     4
# Male name, no gender given         3
# Name: GENDER, dtype: int64
# Distribution of cleaned `is_female` distribution:
# 0.0    239282
# 1.0     32138
# Name: is_female, dtype: int64

# %%
# original summary stat of age variable:
print("Summary statistics of original AGE_AT_INCIDENT variable:")
sentencing_cleaned.AGE_AT_INCIDENT.describe()

# there is an outlier (137 y.o. obs), winsorizing age column to 99.99th percentile
sentencing_cleaned['age_cleaned'] = np.where(sentencing_cleaned.AGE_AT_INCIDENT >= 
                                             sentencing_cleaned.AGE_AT_INCIDENT.quantile(0.9999), 
                                             sentencing_cleaned.AGE_AT_INCIDENT.quantile(0.9999), 
                                             sentencing_cleaned.AGE_AT_INCIDENT)

# printing the summary stat of new age variable
print("Summary statistics of cleaned age variable:")
sentencing_cleaned.age_cleaned.describe()
# Out:
# Summary statistics of original AGE_AT_INCIDENT variable:
# count    268527.000000
# mean         32.360753
# std          11.754197
# min          17.000000
# 25%          23.000000
# 50%          29.000000
# 75%          40.000000
# max         137.000000
# Name: AGE_AT_INCIDENT, dtype: float64
# Summary statistics of cleaned age variable:
# count    268527.00000
# mean         32.35875
# std          11.74226
# min          17.00000
# 25%          23.00000
# 50%          29.00000
# 75%          40.00000
# max          81.00000
# Name: age_cleaned, dtype: float64

# %% [markdown]
# <u>**Cleaning flags (if any)**</u>:
#
# 1. `RACE`:
#     - How should we categorize *biracial* race group?
#     - I recoded `Unknown` and `Biracial` as NaN for each race definition
#     - What does `[Hispanic or Latino]` actually mean? In pset2, why did we not categorize `White/Black [Hispanic or Latino]` into the `is_hisp` definition?
#
#
# 2. `GENDER`:
#     - I recoded rows containing `Unknown` as NaN
#     - `Male name, no gender given` is coded as `Male` (reasonable?).
#
#
# 3. `AGE_AT_INCIDENT`:
#     - As with pset2, I winsorized the age variable

# %% [markdown]
# ## Cleaning datetime variables<a class="anchor" id="datetime-variables"></a>
#
# Here, we:
#
# * Clean up the defendant's date of sentencing (`SENTENCE_DATE`). We'll create a datetime object out of the field, and will separate year, month, and year-month component of the date.
#
# * Add several key treatment variables that will be of interest for the analysis
#
# * Add time relative indicators for the event study estimation

# %%
# do all rows have 12:00:00 AM time?
set([date[-11:] for date in sentencing_cleaned['SENTENCE_DATE']])

# since all rows started with 12:00:00 AM, we can strip that component 
sentencing_cleaned['sentence_date'] = sentencing_cleaned.SENTENCE_DATE.str.replace("12:00:00 AM ", "")

# we clean up the SENTENCE_DATE that have out-of-bound years
sentencing_cleaned['sentence_date'] = [re.sub(r'2[1-9]([0-9]+)', r'20\1', str(date)) 
                                       if bool(re.search(r'2[1-9]([0-9]+)', str(date)))
                                       else str(date) 
                                       for date in sentencing_cleaned.sentence_date]

# converting to datetime
sentencing_cleaned['sentence_date'] = pd.to_datetime(sentencing_cleaned["sentence_date"])

# creating a year, month, date columns 
sentencing_cleaned['sentence_year'] = pd.DatetimeIndex(sentencing_cleaned['sentence_date']).year
sentencing_cleaned['sentence_month'] = pd.DatetimeIndex(sentencing_cleaned['sentence_date']).month
sentencing_cleaned['sentence_day'] = pd.DatetimeIndex(sentencing_cleaned['sentence_date']).day
sentencing_cleaned['sentence_ym'] = sentencing_cleaned['sentence_date'].dt.to_period('M')
# Out:
# {'12:00:00 AM'}

# %%
sentencing_cleaned
# Out:
#              CASE_ID  CASE_PARTICIPANT_ID           RECEIVED_DATE  \
# 0       198055620664          85937621020  08/15/1984 12:00:00 AM
# 1       198055620664          85937621020  08/15/1984 12:00:00 AM
# 2       198055620664          85937621020  08/15/1984 12:00:00 AM
# 3       198055620664          85937621020  08/15/1984 12:00:00 AM
# 4       198055620664          85937621020  08/15/1984 12:00:00 AM
# ...              ...                  ...                     ...
# 272289  597320386308         452719800958  07/18/2022 12:00:00 AM
# 272290  597328542979         452727325242  07/18/2022 12:00:00 AM
# 272291  597341166398         452739650297  07/19/2022 12:00:00 AM
# 272292  597341166398         452739650297  07/19/2022 12:00:00 AM
# 272293  597406808178         452817755138  07/23/2022 12:00:00 AM
#
#                       OFFENSE_CATEGORY  PRIMARY_CHARGE_FLAG       CHARGE_ID  \
# 0                    PROMIS Conversion                False   1242195814523
# 1                    PROMIS Conversion                False   1242198287388
# 2                    PROMIS Conversion                False   1242351605056
# 3                    PROMIS Conversion                False   1242352841488
# 4                    PROMIS Conversion                False   1242356550787
# ...                                ...                  ...             ...
# 272289                    Retail Theft                 True  11294724616133
# 272290  Aggravated Fleeing and Eluding                 True  11295052270826
# 272291     Criminal Damage to Property                 True  11295731072434
# 272292     Criminal Damage to Property                 True  11295731072434
# 272293    UUW - Unlawful Use of Weapon                 True  11310189917611
#
#         CHARGE_VERSION_ID                  DISPOSITION_CHARGED_OFFENSE_TITLE  \
# 0            155656315869                                FIRST DEGREE MURDER
# 1            131513547452                                      HOME INVASION
# 2            176626576281                                FIRST DEGREE MURDER
# 3            176617824190                                FIRST DEGREE MURDER
# 4            131238606761                                      HOME INVASION
# ...                   ...                                                ...
# 272289      1148300237684                                       RETAIL THEFT
# 272290      1148334245809  AGGRAVATED FLEEING OR ATTEMPT TO ELUDE A PEACE...
# 272291      1148405887926   CRIMINAL DAMAGE TO GOVERNMENT SUPPORTED PROPERTY
# 272292      1148405887926   CRIMINAL DAMAGE TO GOVERNMENT SUPPORTED PROPERTY
# 272293      1149901120181                  AGGRAVATED UNLAWFUL USE OF WEAPON
#
#         CHARGE_COUNT        DISPOSITION_DATE DISPOSITION_CHARGED_CHAPTER  \
# 0                  2  12/17/2014 12:00:00 AM                          38
# 1                 14  12/17/2014 12:00:00 AM               38-12-11-A(2)
# 2                  4  12/17/2014 12:00:00 AM                          38
# 3                  5  12/17/2014 12:00:00 AM                          38
# 4                 13  12/17/2014 12:00:00 AM               38-12-11-A(1)
# ...              ...                     ...                         ...
# 272289             1  09/02/2022 12:00:00 AM                         720
# 272290             1  09/06/2022 12:00:00 AM                         625
# 272291             1  08/23/2022 12:00:00 AM                         720
# 272292             1  08/23/2022 12:00:00 AM                         720
# 272293             1  08/31/2022 12:00:00 AM                         720
#
#        DISPOSITION_CHARGED_ACT DISPOSITION_CHARGED_SECTION  \
# 0                            -                   9-1(a)(2)
# 1                          NaN                         NaN
# 2                            -                   9-1(a)(3)
# 3                            -                   9-1(a)(3)
# 4                          NaN                         NaN
# ...                        ...                         ...
# 272289                       5                 16-25(a)(1)
# 272290                       5              11-204.1(a)(4)
# 272291                       5               21-1.01(a)(1)
# 272292                       5               21-1.01(a)(1)
# 272293                       5                24-1.6(a)(1)
#
#        DISPOSITION_CHARGED_CLASS DISPOSITION_CHARGED_AOIC CHARGE_DISPOSITION  \
# 0                              X               0000001607    Nolle On Remand
# 1                              X               0000001847    Nolle On Remand
# 2                              X               0000001608    Nolle On Remand
# 3                              X               0000001608    Nolle On Remand
# 4                              X               0000001846     Plea Of Guilty
# ...                          ...                      ...                ...
# 272289                         4                    16720     Plea Of Guilty
# 272290                         4                    13454     Plea Of Guilty
# 272291                         4                    17490     Plea Of Guilty
# 272292                         4                    17490     Plea Of Guilty
# 272293                         4                    17869     Plea Of Guilty
#
#        CHARGE_DISPOSITION_REASON             SENTENCE_JUDGE  \
# 0                            NaN              John  Mannion
# 1                            NaN              John  Mannion
# 2                            NaN              John  Mannion
# 3                            NaN              John  Mannion
# 4                            NaN          Clayton Jay Crane
# ...                          ...                        ...
# 272289                       NaN               Neera  Walsh
# 272290                       NaN         Steven J Rosenblum
# 272291                       NaN  Catherine Marie Haberkorn
# 272292                       NaN  Catherine Marie Haberkorn
# 272293                       NaN          Patrick  Coughlin
#
#             SENTENCE_COURT_NAME SENTENCE_COURT_FACILITY  \
# 0          District 6 - Markham      Markham Courthouse
# 1          District 6 - Markham      Markham Courthouse
# 2          District 6 - Markham      Markham Courthouse
# 3          District 6 - Markham      Markham Courthouse
# 4          District 6 - Markham      Markham Courthouse
# ...                         ...                     ...
# 272289     District 1 - Chicago             26TH Street
# 272290  District 5 - Bridgeview   Bridgeview Courthouse
# 272291      District 2 - Skokie       Skokie Courthouse
# 272292      District 2 - Skokie       Skokie Courthouse
# 272293     District 6 - Markham      Markham Courthouse
#
#                       SENTENCE_PHASE           SENTENCE_DATE SENTENCE_TYPE  \
# 0                Original Sentencing  06/02/1986 12:00:00 AM    Conversion
# 1                Original Sentencing  06/02/1986 12:00:00 AM    Conversion
# 2                Original Sentencing  06/02/1986 12:00:00 AM    Conversion
# 3                Original Sentencing  06/02/1986 12:00:00 AM    Conversion
# 4       Amended/Corrected Sentencing  10/16/2014 12:00:00 AM        Prison
# ...                              ...                     ...           ...
# 272289           Original Sentencing  09/02/2022 12:00:00 AM     Probation
# 272290           Original Sentencing  09/06/2022 12:00:00 AM   Supervision
# 272291  Amended/Corrected Sentencing  08/24/2022 12:00:00 AM     Probation
# 272292           Original Sentencing  08/23/2022 12:00:00 AM     Probation
# 272293           Original Sentencing  08/31/2022 12:00:00 AM     Probation
#
#         CURRENT_SENTENCE_FLAG                     COMMITMENT_TYPE  \
# 0                        True                        Natural Life
# 1                        True  Illinois Department of Corrections
# 2                        True                        Natural Life
# 3                        True                        Natural Life
# 4                        True  Illinois Department of Corrections
# ...                       ...                                 ...
# 272289                   True                Drug Court Probation
# 272290                   True                   Court Supervision
# 272291                   True                           Probation
# 272292                  False                           Probation
# 272293                   True                           Probation
#
#        COMMITMENT_TERM COMMITMENT_UNIT  LENGTH_OF_CASE_in_Days  \
# 0                  NaN             NaN                   619.0
# 1                 30.0         Year(s)                   619.0
# 2                  NaN             NaN                   619.0
# 3                  NaN             NaN                   619.0
# 4                 30.0         Year(s)                 10982.0
# ...                ...             ...                     ...
# 272289             2.0            Days                     0.0
# 272290            18.0          Months                     0.0
# 272291             1.0         Year(s)                     7.0
# 272292             1.0            Days                     6.0
# 272293            24.0          Months                     1.0
#
#         AGE_AT_INCIDENT   RACE  GENDER   INCIDENT_CITY  \
# 0                  27.0  Black    Male             NaN
# 1                  27.0  Black    Male             NaN
# 2                  27.0  Black    Male             NaN
# 3                  27.0  Black    Male             NaN
# 4                  27.0  Black    Male             NaN
# ...                 ...    ...     ...             ...
# 272289             54.0  Black    Male         Chicago
# 272290             19.0  Black    Male  Evergreen Park
# 272291             27.0  Black    Male         Chicago
# 272292             27.0  Black    Male         Chicago
# 272293             19.0  Black  Female     Park Forest
#
#            INCIDENT_BEGIN_DATE INCIDENT_END_DATE  \
# 0       08/09/1984 12:00:00 AM               NaN
# 1       08/09/1984 12:00:00 AM               NaN
# 2       08/09/1984 12:00:00 AM               NaN
# 3       08/09/1984 12:00:00 AM               NaN
# 4       08/09/1984 12:00:00 AM               NaN
# ...                        ...               ...
# 272289  07/18/2022 12:00:00 AM               NaN
# 272290  07/18/2022 12:00:00 AM               NaN
# 272291  02/06/2022 12:00:00 AM               NaN
# 272292  02/06/2022 12:00:00 AM               NaN
# 272293  07/23/2022 12:00:00 AM               NaN
#
#                  LAW_ENFORCEMENT_AGENCY LAW_ENFORCEMENT_UNIT  \
# 0                   CHICAGO POLICE DEPT                  NaN
# 1                   CHICAGO POLICE DEPT                  NaN
# 2                   CHICAGO POLICE DEPT                  NaN
# 3                   CHICAGO POLICE DEPT                  NaN
# 4                   CHICAGO POLICE DEPT                  NaN
# ...                                 ...                  ...
# 272289                       CHICAGO PD                  NaN
# 272290                EVERGREEN PARK PD                  NaN
# 272291  COOK COUNTY SHERIFF (IL0160000)                  NaN
# 272292  COOK COUNTY SHERIFF (IL0160000)                  NaN
# 272293                   PARK FOREST PD                  NaN
#
#                    ARREST_DATE      FELONY_REVIEW_DATE FELONY_REVIEW_RESULT  \
# 0       08/15/1984 12:00:00 AM  08/15/1984 12:00:00 AM   Charge(S) Approved
# 1       08/15/1984 12:00:00 AM  08/15/1984 12:00:00 AM   Charge(S) Approved
# 2       08/15/1984 12:00:00 AM  08/15/1984 12:00:00 AM   Charge(S) Approved
# 3       08/15/1984 12:00:00 AM  08/15/1984 12:00:00 AM   Charge(S) Approved
# 4       08/15/1984 12:00:00 AM  08/15/1984 12:00:00 AM   Charge(S) Approved
# ...                        ...                     ...                  ...
# 272289  07/18/2022 09:20:00 AM  07/18/2022 12:00:00 AM             Approved
# 272290  07/18/2022 11:11:00 PM  07/18/2022 12:00:00 AM             Approved
# 272291                     NaN  08/02/2022 12:00:00 AM             Approved
# 272292                     NaN  08/02/2022 12:00:00 AM             Approved
# 272293  07/23/2022 05:09:00 AM  07/23/2022 12:00:00 AM             Approved
#
#               ARRAIGNMENT_DATE        UPDATED_OFFENSE_CATEGORY is_black  \
# 0       09/21/1984 12:00:00 AM               PROMIS Conversion     True
# 1       09/21/1984 12:00:00 AM               PROMIS Conversion     True
# 2       09/21/1984 12:00:00 AM               PROMIS Conversion     True
# 3       09/21/1984 12:00:00 AM               PROMIS Conversion     True
# 4       09/21/1984 12:00:00 AM               PROMIS Conversion     True
# ...                        ...                             ...      ...
# 272289  09/02/2022 12:00:00 AM                    Retail Theft     True
# 272290  09/06/2022 12:00:00 AM  Aggravated Fleeing and Eluding     True
# 272291  08/17/2022 12:00:00 AM     Criminal Damage to Property     True
# 272292  08/17/2022 12:00:00 AM     Criminal Damage to Property     True
# 272293  08/30/2022 12:00:00 AM    UUW - Unlawful Use of Weapon     True
#
#        is_hisp is_white  is_female  age_cleaned sentence_date  sentence_year  \
# 0        False    False        0.0         27.0    1986-06-02           1986
# 1        False    False        0.0         27.0    1986-06-02           1986
# 2        False    False        0.0         27.0    1986-06-02           1986
# 3        False    False        0.0         27.0    1986-06-02           1986
# 4        False    False        0.0         27.0    2014-10-16           2014
# ...        ...      ...        ...          ...           ...            ...
# 272289   False    False        0.0         54.0    2022-09-02           2022
# 272290   False    False        0.0         19.0    2022-09-06           2022
# 272291   False    False        0.0         27.0    2022-08-24           2022
# 272292   False    False        0.0         27.0    2022-08-23           2022
# 272293   False    False        1.0         19.0    2022-08-31           2022
#
#         sentence_month  sentence_day sentence_ym
# 0                    6             2     1986-06
# 1                    6             2     1986-06
# 2                    6             2     1986-06
# 3                    6             2     1986-06
# 4                   10            16     2014-10
# ...                ...           ...         ...
# 272289               9             2     2022-09
# 272290               9             6     2022-09
# 272291               8            24     2022-08
# 272292               8            23     2022-08
# 272293               8            31     2022-08
#
# [272294 rows x 51 columns]

# %%
# defining the treatment variables
sentencing_cleaned['sa_office_period'] = np.where(sentencing_cleaned.sentence_ym >= "2016-12", # SA Foxx assumed office in Dec 1, 2016
                                                  True, False)   

sentencing_cleaned['sa_timedelta'] = (sentencing_cleaned.sentence_year - 2016)*12 + (sentencing_cleaned.sentence_month - 12)

sentencing_cleaned['sa_timedelta_days'] = (sentencing_cleaned['sentence_date'] - pd.to_datetime("2016-12-01")).dt.days

# Bail Reform Act
sentencing_cleaned['BRA_period'] = np.where(sentencing_cleaned.sentence_ym >= "2017-06", # Bail Reform Act
                                            True, False)

sentencing_cleaned['BRA_timedelta'] = (sentencing_cleaned.sentence_year - 2017)*12 + (sentencing_cleaned.sentence_month - 6)

sentencing_cleaned['BRA_timedelta_days'] = (sentencing_cleaned['sentence_date'] - pd.to_datetime("2017-06-12")).dt.days

# %% [markdown]
# <u>**Cleaning flags (if any)**</u>:
#
# 1. `SENTENCE_DATE`:
#     - All out-of-bounds years (29, 22, etc instead of 20XX) are converted into 20XX.
#     - How do we clean up 2023-2066 though? (Currently, we're filtering against values > 2022 in the filtering stage)
#
#
# 2. Key treatment-related time variables:
#     - SA Kim Foxx entry: Value = 1 if December 2016 onwards, 0 if otherwise
#     - Bail reform act: Value = 1 if June 2017 onwards, 0 if otherwise
#     - For both indicators, relative time indicators are defined relative to the timing that corresponds to the start of value = 1

# %% [markdown]
# ## Cleaning sentencing-related variables<a class="anchor" id="sentencing-vars"></a>

# %% [markdown]
# Here, we:
#
# * Clean up sentencing term data, based on their commitment units
# * Defining defendant's incarceration status
# * Recategorize offense types

# %% [markdown]
# First up, we clean the sentencing term data, storing them in both days and years format:

# %%
# what sentence units are available in the sentencing_cleaned data?
print("Commitment units in the original data:")
sentencing_cleaned.COMMITMENT_UNIT.value_counts()

# first, we convert the commitment_term into a numeric
# before that, because we have multiple categories to be cleaned, we'll first create a dictionary for the 
# string correspondences
replace_dict = {'wrap': "", 
                "two": "2", 
                "months": "", 
                "1,154.00": "1154", 
                "`" : ""}

# replacing w/ the string correspondence 
sentencing_cleaned['sentencing_num'] = pd.to_numeric(sentencing_cleaned['COMMITMENT_TERM'].replace(replace_dict, 
                                                                                                   regex=True))

# we're going to use np.select. as such, we store the criteria (units) and codes (days_equiv) in different objects
units = [sentencing_cleaned.COMMITMENT_UNIT == "Year(s)",
        sentencing_cleaned.COMMITMENT_UNIT == "Months", 
        sentencing_cleaned.COMMITMENT_UNIT == "Days", 
        sentencing_cleaned.COMMITMENT_UNIT == "Weeks", 
        sentencing_cleaned.COMMITMENT_UNIT == "Hours", 
        sentencing_cleaned.COMMITMENT_UNIT == "Natural Life",
        sentencing_cleaned.COMMITMENT_UNIT.isin(['Term', 'Dollars', 'Pounds', 'Ounces', 'Kilos'])]

# assigning the codes - nan to the excluded units
days_equiv = [(sentencing_cleaned.sentencing_num * 365), 
              (sentencing_cleaned.sentencing_num * 30.5), 
              (sentencing_cleaned.sentencing_num * 1), 
              (sentencing_cleaned.sentencing_num * 7), 
              (sentencing_cleaned.sentencing_num * 1/24), 
              (100 - sentencing_cleaned.age_cleaned)*365, 
              np.nan]

# generating the days units of each COMMITMENT_UNIT type. 
sentencing_cleaned['sentencing_term_d'] = np.select(units, days_equiv)
sentencing_cleaned.loc[(pd.isnull(sentencing_cleaned.COMMITMENT_TERM)) & 
                       (pd.isnull(sentencing_cleaned.COMMITMENT_UNIT)), 
                       'sentencing_term_d'] = np.nan       # assigning NaN to these rows because they got coded as 0
sentencing_cleaned['sentencing_term_y'] = sentencing_cleaned.sentencing_term_d / 365

# summary statistics of the sentencing term in year. 
sentencing_cleaned['sentencing_term_y'].describe()
# Out:
# Commitment units in the original data:
# Year(s)         195920
# Months           62405
# Days              8961
# Term              2349
# Natural Life       733
# Dollars             77
# Hours               36
# Weeks               21
# Pounds               4
# Ounces               1
# Kilos                1
# Name: COMMITMENT_UNIT, dtype: int64
# count    2.680690e+05
# mean     1.905460e+01
# std      5.550306e+03
# min      0.000000e+00
# 25%      1.504110e+00
# 50%      2.000000e+00
# 75%      3.000000e+00
# max      2.032012e+06
# Name: sentencing_term_y, dtype: float64

# %% [markdown]
# Next, we define whether the defendant is incarcerated or in probation:

# %%
# defining whether incarcerated (if COMMITMENT_TYPE == Illinois Department of Correction)
sentencing_cleaned['is_incarcerated'] = np.where(sentencing_cleaned['COMMITMENT_TYPE'] == "Illinois Department of Corrections", 
                                                 True, False)

# defining whether is_on_probation - based on the sentencing_data_glossary
sentencing_cleaned['is_on_probation'] = np.where(sentencing_cleaned['COMMITMENT_TYPE'].isin(["Probation", 
                                                                                             "710/410 Probation", 
                                                                                             "Intensive Probation Services", 
                                                                                             "Mental Health Probation", 
                                                                                             "Intensive Drug Probation Services", 
                                                                                             "Drug Court Probation", 
                                                                                             "Sex Offender Probation", 
                                                                                             "Gang Probation", 
                                                                                             "2nd Chance Probation", 
                                                                                             "Veteran's Court Probation", 
                                                                                             "Repeat Offender Probation", 
                                                                                             "Domestic Violence Probation"]), 
                                                 True, False)

# %% [markdown]
# Next, we clean up/regroup the offense categories:

# %%
# stripping the offense category of "Aggravated" keyword
sentencing_cleaned['regrouped_offense'] = sentencing_cleaned.UPDATED_OFFENSE_CATEGORY.str.replace("Aggravated ", "")

# printing the number of unique offense categories in the raw + cleaned data
print("Number of unique `UPDATED_OFFENSE_CATEGORY`: " + str(len(sentencing_cleaned.UPDATED_OFFENSE_CATEGORY.unique()))) 
print("Number of unique `regrouped_offense`: " + str(len(sentencing_cleaned.regrouped_offense.unique())))
# Out:
# Number of unique `UPDATED_OFFENSE_CATEGORY`: 80
# Number of unique `regrouped_offense`: 76

# %%
# all misdemeanors and type-4 offenses are considered eligible for bail reform act.
sentencing_cleaned['eligible_offense'] = np.where(sentencing_cleaned.DISPOSITION_CHARGED_CLASS.isin(['A', 'B', 'C', '4']),
                                                 True, False)

# %% [markdown]
# <u>**Cleaning flags (if any)**</u>:
#
# 1. `sentencing_term`:
#     * In pset3, we did a `fillna(20)` on the cleaned age variable to calculate the terms for `Natural Life` units. I'm not sure if we should do this and the rationale behind this. So, I'm skipping that step.
#     * There are some rows with `COMMITMENT_TERM == 0` and non-null `COMMITMENT_UNIT` (e.g. 0 years, 0 months, etc.). Should we filter for these rows when preparing the analysis-ready dataset?
#
#
# 2. Incarceration statuses:
#     * Added `is_on_probation` status, which includes most `COMMITMENT_TYPES` that contain the word "PROBATION"
#
#
# 3. `DISPOSITION_CHARGED_CLASS`:
#     * These codes could be important for the Bail Reform Act policy. However, not sure what codes Z, O, P and U mean
#
#
# 4. How should we ideally group the offense types? How granular should the offense groupings be?
#
#
# 5. `eligible_offense`:
#     * Eligible offenses for bail reform act: misdemeanors type A, B, C and felony level 4 (reasonable?). I couldn't find the exact formal definition of "non-violent", low-level offenses and misdemeanors.

# %% [markdown]
# ## Filtering to prepare analysis-ready dataset<a class="anchor" id="filtering"></a>

# %% [markdown]
# Here, we:
#
# * Filter against years that are above 2022
# * Filter against 0 `COMMITMENT_TERM` and non-null `COMMITMENT_UNIT` (e.g. 0 years, 0 months, etc.)
# * Filter to cases where only one participant is charged, since cases with >1 participant might have complications like plea bargains/informing from other participants affecting the sentencing of the focal participant (filtering to `PRIMARY_CHARGE_FLAG == True` and `CURRENT_SENTENCE_FLAG == True`)

# %%
# Printing shape prior to filters
print("Shape of data frame prior to filters: " + str(sentencing_cleaned.shape))

# filtering against years above September 2022 (the time of last update) 
sentencing_analysis = sentencing_cleaned[sentencing_cleaned.sentence_ym <= "2022-09"].copy()

# filtering against 0 COMMITMENT TERM and non-null COMMITMENT_UNIT (0 years, 0 months, etc.)
sentencing_analysis = sentencing_analysis[(sentencing_analysis.sentencing_num != 0) & 
                                          (~pd.isnull(sentencing_analysis.COMMITMENT_UNIT))].copy()

# filtering for cases where primary charge flag == True and current sentence flag == True
sentencing_analysis = sentencing_analysis[(sentencing_analysis.PRIMARY_CHARGE_FLAG == True) & 
                                        (sentencing_analysis.CURRENT_SENTENCE_FLAG == True)].copy()

# Printing shape prior to filters
print("Shape of data frame prior to filters: " + str(sentencing_analysis.shape))

# Is CASE_PARTICIPANT_ID unique within the data frame?
print("Number of unique `CASE_PARTICIPANT_ID` in the dataframe: " + 
      str(len(pd.unique(sentencing_analysis.CASE_PARTICIPANT_ID))))
# Out:
# Shape of data frame prior to filters: (272294, 64)
# Shape of data frame prior to filters: (186824, 64)
# Number of unique `CASE_PARTICIPANT_ID` in the dataframe: 186824

# %% [markdown]
# ## Regrouping offenses using the CJARS tool<a class="anchor" id="cjars"></a>

# %% [markdown]
# Here, we will regroup the offenses to get the UCCS, MFJ, and NCRP codes. We will rely on the [CJARS tool](https://cjars-toc.isr.umich.edu/), using `DISPOSITION_CHARGED_OFFENSE_TITLE` as the input data for the CJARS tool.
#
# Run the following code chunk if first time running the offense-regrouping job:

# %%
# this code chunk is to be run only if first time doing the offense-regrouping job (across all devices)
# filtering only for two columns (in accordance with https://cjars-toc.isr.umich.edu/wp-content/uploads/2022/07/TOC_Instructions.pdf) 
# as input data for the CJARS Text-Based Offense Classification.
# for the offense regrouping, we use the UPDATED_OFFENSE_CATEGORY field, instead of the regrouped_offense field 
# that we've just created.
#sentencing_CJARS = sentencing_analysis[['CASE_PARTICIPANT_ID', 'DISPOSITION_CHARGED_OFFENSE_TITLE']].copy()

# exporting the data to csv
#sentencing_CJARS.to_csv('../data/csv/sentencing_CJARS_input.csv', index = False)
# the above data will be passed to the TOC job queue (uploaded to the website manually), 
# and after the data has been processed (takes some time), we need to download the resulting XLSX file.

# %% [markdown]
# Make sure that the Excel results are already downloaded and placed within the `xls` directory of the Github repo. Then, run the following chunks to merge the analysis dataset with the CJARS results dataframe.

# %%
# next, we load the CJARS results
CJARS_results = pd.read_excel('../data/xls/CJARS_results.xlsx', sheet_name='TOC_Result')

# getting the UCCS, schema
CJARS_UCCS = pd.read_excel('../data/xls/CJARS_results.xlsx', sheet_name='UCCS_Schema')

# merging the results dataframe with the schema DF
CJARS_results = pd.merge(left=CJARS_results, right=CJARS_UCCS, how="left", left_on = "uccs_code", right_on = "uccs_code")

# %%
# what does the data look like?
CJARS_results

# getting the p-score summary
CJARS_results.probability.describe()

# how many proportion of rows have probability scores lower than 50%?
print("Fraction of rows with scores < .5: " + str(np.mean(CJARS_results.probability < .5)))

# what is the proportion of each charge descriptions?
CJARS_results.charge_desc.value_counts(normalize = True)
# Out:
#         CASE_PARTICIPANT_ID  \
# 0               85937621020
# 1               79292385441
# 2              110240551636
# 3              113262313456
# 4              116618790525
# ...                     ...
# 186819         452016441937
# 186820         452059325742
# 186821         452148555445
# 186822         452317367149
# 186823         452727325242
#
#                         DISPOSITION_CHARGED_OFFENSE_TITLE  uccs_code  \
# 0                                     FIRST DEGREE MURDER       1010
# 1                                     FIRST DEGREE MURDER       1010
# 2                            MURDER/INTENT TO KILL/INJURE       1011
# 3                                       2ND DEGREE MURDER       1010
# 4                            MURDER/INTENT TO KILL/INJURE       1011
# ...                                                   ...        ...
# 186819                       DRIVING ON SUSPENDED LICENSE       6010
# 186820                        AGG UUW/LOADED/NO FCCA/FOID       6010
# 186821                         DRIVING ON REVOKED LICENSE       6010
# 186822                         DRIVING ON REVOKED LICENSE       6010
# 186823  AGGRAVATED FLEEING OR ATTEMPT TO ELUDE A PEACE...       6010
#
#         probability  mfj_code ncrp_code ncic_code nibrs_code  \
# 0          0.999990        10       010       NaN        09A
# 1          0.999990        10       010       NaN        09A
# 2          0.999070        11       011       NaN        NaN
# 3          1.000000        10       010       NaN        09A
# 4          0.999070        11       011       NaN        NaN
# ...             ...       ...       ...       ...        ...
# 186819     0.999993       475       550      5499        NaN
# 186820     0.428645       475       550      5499        NaN
# 186821     0.999953       475       550      5499        NaN
# 186822     0.999953       475       550      5499        NaN
# 186823     0.999983       475       550      5499        NaN
#
#                    charge_desc  offense_category_code  \
# 0                       Murder                      1
# 1                       Murder                      1
# 2             Attempted Murder                      1
# 3                       Murder                      1
# 4             Attempted Murder                      1
# ...                        ...                    ...
# 186819  Traffic Offense, Minor                     84
# 186820  Traffic Offense, Minor                     84
# 186821  Traffic Offense, Minor                     84
# 186822  Traffic Offense, Minor                     84
# 186823  Traffic Offense, Minor                     84
#
#            offense_category_desc  offense_type_code offense_type_desc
# 0                         Murder                  1           Violent
# 1                         Murder                  1           Violent
# 2                         Murder                  1           Violent
# 3                         Murder                  1           Violent
# 4                         Murder                  1           Violent
# ...                          ...                ...               ...
# 186819  Traffic offenses - minor                  6  Criminal traffic
# 186820  Traffic offenses - minor                  6  Criminal traffic
# 186821  Traffic offenses - minor                  6  Criminal traffic
# 186822  Traffic offenses - minor                  6  Criminal traffic
# 186823  Traffic offenses - minor                  6  Criminal traffic
#
# [186824 rows x 13 columns]
# count    186824.000000
# mean          0.928803
# std           0.125327
# min           0.160096
# 25%           0.913383
# 50%           0.997146
# 75%           0.999510
# max           1.000000
# Name: probability, dtype: float64
# Fraction of rows with scores < .5: 0.04508521389114889
# Possession/Use of Unspecified Drug                            0.165867
# Theft, Value Unknown                                          0.117469
# Driving Under the Influence of Alcohol                        0.082543
# Traffic Offense, Minor                                        0.078475
# Burglary                                                      0.077469
# Weapons Offense                                               0.074455
# Distribution, Drug Unspecified                                0.062508
# Aggravated Assault                                            0.050218
# Armed Robbery                                                 0.047435
# Forgery/Fraud                                                 0.033529
# Contempt of Court/Violate Court Order                         0.030526
# Distribution Marijuana                                        0.024563
# Auto Theft                                                    0.018242
# Possession/Use of Marijuana                                   0.016497
# Destruction of Property                                       0.010978
# Obstruction/Resisting                                         0.010079
# Burglary, Attempted                                           0.007809
# Child Molestation                                             0.007419
# Criminal Trespass                                             0.006621
# Habitual Offender                                             0.005915
# Possession/Use, Drug Unspecified, Attempted                   0.005342
# Armed Robbery, Attempted                                      0.004603
# Commercialized Vice                                           0.004213
# Attempted Murder                                              0.004196
# Murder                                                        0.004116
# Disorderly Conduct Offense                                    0.004041
# Kidnapping                                                    0.003003
# Violent Offense, Other                                        0.002928
# Extortion/Threat                                              0.002596
# Possession of amphetamines                                    0.002430
# Unarmed Robbery, Attempted                                    0.002045
# Aggravated Assault, Attempted                                 0.001986
# Sexual Assault, Attempted                                     0.001948
# Other Court Offense                                           0.001745
# Fraudulent Drug Offense                                       0.001659
# Driving While Intoxicated                                     0.001654
# Hit and Run with Bodily Injury                                0.001477
# Arson                                                         0.001413
# Forgery/Fraud, Attempted                                      0.001269
# Public Order Offense, Other                                   0.001242
# Auto Theft, Attempted                                         0.001044
# Hit and Run Driving with Property Damage                      0.000915
# Distribution of amphetamines                                  0.000856
# Invasion of Privacy                                           0.000781
# Rape                                                          0.000685
# Other Property Offense                                        0.000648
# Involuntary Manslaughter                                      0.000637
# Escape from Custody                                           0.000610
# Weapons Offense, Attempted                                    0.000578
# Theft, Value Unknown, Attempted                               0.000562
# Obstruction/Resisting, Attempted                              0.000551
# Distribution Cocaine or Crack                                 0.000546
# Child Molestation, Attempted                                  0.000541
# Vehicular Manslaughter                                        0.000482
# Possession of Property Crime Tools                            0.000444
# Offense Against Morals/Decency                                0.000418
# Receiving Stolen Property                                     0.000407
# Drug Paraphernalia                                            0.000391
# Conspiracy to Commit Murder                                   0.000391
# Assault of an Officer                                         0.000391
# Bribery/Conflict of Interest                                  0.000337
# Arson, Attempted                                              0.000327
# Driving Under the Influence of Drugs                          0.000316
# Distribution, Drug Unspecified, Conspiracy                    0.000316
# Distribution Heroin                                           0.000305
# Contempt of Court/Violate Court Order, Attempted              0.000289
# Distribution Marijuana, Attempted                             0.000230
# Child Abuse                                                   0.000230
# Possession/Use of Heroin                                      0.000230
# Sexual Assault, Conspiracy                                    0.000214
# Probation Violation                                           0.000209
# Escape from Custody, Conspiracy                               0.000193
# Possession of amphetamines, Attempted                         0.000182
# Possession/Use of Cocaine or Crack                            0.000171
# Financial Crimes                                              0.000161
# Destruction of Property, Attempted                            0.000155
# Kidnapping, Attempted                                         0.000123
# Aggravated Assault, Conspiracy                                0.000123
# Petty Theft (=<$500)                                          0.000123
# Possession of prescription drugs                              0.000112
# Other Drug Offense                                            0.000107
# Human Trafficking, Sex - child                                0.000080
# Taxation Offense                                              0.000075
# Escape from Custody, Attempted                                0.000075
# Human Trafficking, Unspecified - adult or no age specified    0.000064
# Other Property Offense, Attempt                               0.000064
# Financial Crimes Conspiracy                                   0.000059
# Possession/Use of Marijuana, Attempted                        0.000059
# Auto Theft, Conspiracy                                        0.000054
# Invasion of Privacy, Attempted                                0.000054
# Contributing to the Delinquency of a Minor                    0.000054
# Immigration Violation                                         0.000048
# Other Court Offense, Attempted                                0.000043
# Unarmed Robbery, Conspiracy                                   0.000043
# Extortion/Threat, Attempted                                   0.000043
# Sale of Stolen Property                                       0.000043
# Commercialized Vice, Attempted                                0.000032
# Grand Theft (>$500)                                           0.000032
# Armed Robbery, Conspiracy                                     0.000027
# Possession of prescription drugs, Attempted                   0.000027
# Bribery/Conflict of Interest, Attempt                         0.000021
# Possession of Property Crime Tools, Attempted                 0.000016
# Distribution Marijuana, Conspiracy                            0.000016
# Sexual Assault                                                0.000016
# Unspecified Homicide                                          0.000016
# Family or Custody Related Offense                             0.000011
# Human Trafficking, Labor - adult or no age specified          0.000011
# Public Order Offense, Other, Attempted                        0.000005
# Voluntary Manslaughter                                        0.000005
# Unauthorized use of Vehicle                                   0.000005
# Distribution of amphetamines, Attempted                       0.000005
# Distribution of amphetamines, Conspiracy                      0.000005
# Distribution of opioids                                       0.000005
# Driving Under the Influence of Drugs, Attempted               0.000005
# Distribution Other Controlled Substances                      0.000005
# Arson, Conspiracy                                             0.000005
# Fraudulent Drug Offense, Attempted                            0.000005
# Rape, Attempted                                               0.000005
# Theft, Value Unknown, Conspiracy                              0.000005
# Name: charge_desc, dtype: float64

# %% [markdown]
# The output suggests that around 4.5% of our `sentencing_analysis` `CASE_PARTICIPANT_ID` rows have probability scores lower than 50%.

# %%
# merging the sentencing_analysis data with the CJARS_results based on CASE_PARTICIPANT_ID
sentencing_analysis = pd.merge(left = sentencing_analysis, 
                               right = CJARS_results, 
                               how = 'inner', 
                               left_on = "CASE_PARTICIPANT_ID", 
                               right_on = "CASE_PARTICIPANT_ID")

# printing the shape of the new DF
sentencing_analysis.shape
# Out:
# (186824, 76)

# %% [markdown]
# After merging the `sentencing_analysis` data with the CJARS case participant-offense group correspondence, we export the resulting final data as the `sentencing_analysis.csv`:

# %%
# exporting the data to csv
sentencing_analysis.to_csv('../data/csv/sentencing_analysis.csv', index = False)

# %% [markdown]
# <u>**Cleaning flags (if any)**</u>:
#
# 1. Filtering for `sentence_year`:
#     - Do we need to filter year from below e.g. set minimum year?
#
#
# 2. Here, I'm not dropping any non-sensical judge names 'cos the main analysis does not necessarily relate to the judges' name.
#
#
# 3. When we filter for `PRIMARY_CHARGE_TRUE == True & CURRENT_SENTENCE_FLAG == True`, we're effectively removing **past**, and **non-primary** charges rows. This leaves us only with **current, primary charges**.
#
#
# 4. For the CJARS code classification:
#     - Do we need to set some sort of threshold for the UCCS probability score? We're currently using the `DISPOSITION_CHARGED_OFFENSE_TITLE` for the CJARS merging.
#     - Should we use `UPDATED_OFFENSE_CATEGORY` instead? We were thinking of using the `DISPOSITION_CHARGED_OFFENSE_TITLE` because the column contains longer description than the `UPDATED_OFFENSE_CATEGORY` column.
#     - Our current CJARS code classification results in 119 unique charges. But the distribution is pretty sparse (has even more categories than the `regrouped_offense` column) -- do we need to further recategorize the smaller groups into one larger category?
